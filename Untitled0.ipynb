# %% [markdown]
# <a href="https://colab.research.google.com/github/TolstyiK0t/TolstyiK0t/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


df =pd.read_csv('/content/sample_data/california_housing_train.csv')
new_sample_df = df.groupby(['housing_median_age'])['population'].sum()
new_sample_df.plot()
plt.show()
#df.head(100)
